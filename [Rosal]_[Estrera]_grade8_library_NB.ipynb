# %%
import requests
import firebase_admin
from firebase_admin import credentials, db

github_raw_url = "https://raw.githubusercontent.com/vexzz-tuff/-Rosal---Estrera--grade8-library-Repo/refs/heads/main/books.json"

response = requests.get(github_raw_url)
book_data = response.json()

if not firebase_admin._apps:
    cred = credentials.Certificate("firebase_key.json")
    firebase_admin.initialize_app(cred, {
        'databaseURL': 'https://rosal-estrera-library-db-default-rtdb.asia-southeast1.firebasedatabase.app/'
    })

ref = db.reference('/')
ref.set(book_data)

print("Full Database Display")
print(ref.get())

print("\nLibrary Inventory Report")
total_library_books = 0

for book in book_data['books']:
    title = book['title']
    available = book['details']['available']
    copies = book['details']['copies']

    print(f"Book Title: {title}  Available: {available}")

    total_library_books += copies

print(f"\nTotal number of books in the library: {total_library_books}")
# Out:
# Full Database Display
# {'books': [{'author': 'Juan Dela Cruz', 'details': {'available': 3, 'copies': 5}, 'id': 2001, 'title': 'Introduction to Python'}, {'author': 'Maria Santos', 'details': {'available': 2, 'copies': 4}, 'id': 2002, 'title': 'Data Structures Basics'}, {'author': 'Carlos Reyes', 'details': {'available': 6, 'copies': 6}, 'id': 2003, 'title': 'Web Development Essentials'}]}
#
# Library Inventory Report
# Book Title: Introduction to Python  Available: 3
# Book Title: Data Structures Basics  Available: 2
# Book Title: Web Development Essentials  Available: 6
#
# Total number of books in the library: 15
